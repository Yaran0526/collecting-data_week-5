# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghistorian/jekyll/blob/Issue-3052/assets/corpus-analysis-with-spacy/corpus-analysis-with-spacy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Female poets Analysis with spaCy
# ## by Yaran Lu

# %% [markdown]
# ### Introduction
#
# ### Research Questions
# This project use spacy to analyze the linguistic features of the poetic works of four female writers around the 19th century, such as word choice, syntactic structure, etc., and explore the correlation between these features and female themes (such as self-perception, emotional experience, female identity, etc.).
#
# The importance of this research question is that by analyzing the poetic works of female writers and using spacy for in-depth research, it can help us gain a deeper understanding of female literature, female perspectives, and the manifestation of gender in literary creation. This helps unearth the literary achievements of female writers, expands awareness of female voices and perspectives, and may help eliminate gender bias and promote gender equality in the literary field.
#
# ### Brief Description
# (1) The corpus itself
# This corpus includes 4 files, which are excerpts from poems by 4 female writers. Poetry was chosen as the research object of this project because among many literary genres, poetry can best reflect the characteristics of language and diction. These four female writers all had an important position in the world literary world in the 19th century.
# they are, respectively:
# Sonnets from the Portuguese. It is a collection of 44 love sonnets written by the British poet Elizabeth Barrett Browning (1806.3.6-1861.6.29).
# Poems written by the British poet Christina Rossetti (1830.12.5-1894.12.29). It contains her famous poem "Goblin Market" and other poetries.
# Poems written by American poet Edna St. Vincent Millay (1892.2.22-1950.10.19). Millay won the 1923 Pulitzer Prize for Poetry.
# Poems by Emily Dickinson, Series One. This is an excerpt from the first series of her collection of works written by American poet Emily Dickinson (1830.12.10-1886.5.15).
#
# (2) Target audience and the intended use of the corpus
# The target audience of this project is lovers and researchers of British and American literature or women's literature.
# The analysis of this project will help them understand the characteristics of these four female writers in poetry creation in the form of data analysis.
#
# (3) Text selection criteria
# This project selected four of the most representative female writers of the 19th century, namely two British writers and two American writers. The selected works are also the most representative or special works in their creative careers. Due to the space limitations of this project, the entire collection of poems cannot be used, and the previous parts of the collection are excerpted for study.
#
# (4) The data collection process
# The txt data of the corpus is downloaded from the official website of Project Gutenberg, the URL is https://www.gutenberg.org/
#
# (5) Cleaning and/or preprocessing steps
# This project uses regular expressions to remove extra whitespace characters from the text, and trim the text to remove leading and trailing spaces.
#
# (6) Annotations that I’ve added and tools that are used for that
# In the code, the Spacy library is used, which provides some NLP functions, including part-of-speech tagging, lemmatization, named entity recognition, etc. Here are the functions and tools used in this code:
# Part-of-Speech Tagging: Get the part-of-speech of each word through token.pos_.
# Lemmatization: Use token.lemma_ to get the token (basic form) of each word.
# Named Entity Recognition: Use doc.ents to get named entities in text and recognize their tags.
# These tools are applied to a given text for part-of-speech tagging, tokenization, and named entity recognition.
#
# (7) The format of the files in the corpus (in this case, probably txt and csv), as well as the description of the columns in the CSV file.
# The code handles two file formats: .txt and .csv. The .txt file contains text content, while the .csv file contains metadata information. The CSV file contains some columns, and the code renames one of the columns according to specific needs.
#
#
# (8) The quality checks
# The code creates a new DataFrame final_paper_df by merging text and metadata. During this process, only those rows that have both paper content and metadata information are retained, possibly as a quality control method to ensure data integrity and correspondence.

# %%
# !pip install spaCy
# !pip install plotly
# !pip install nbformat==5.1.2
# Out:
# Requirement already satisfied: spaCy in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.1.2)
# Requirement already satisfied: setuptools in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spaCy) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spaCy) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spaCy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spaCy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spaCy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spaCy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from jinja2->spaCy) (2.1.1)
# Requirement already satisfied: plotly in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: nbformat==5.1.2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (5.1.2)
# Requirement already satisfied: ipython-genutils in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from nbformat==5.1.2) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from nbformat==5.1.2) (5.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from nbformat==5.1.2) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from nbformat==5.1.2) (5.3.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.2) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat==5.1.2) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat==5.1.2) (2.5.2)

# %%
import spacy

# !spacy download en_core_web_sm

import os

from spacy import displacy

import pandas as pd
pd.options.mode.chained_assignment = None 

import plotly.graph_objects as go
import plotly.express as px
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 4.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/yaranlu/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
texts = []
file_names = []

for _file_name in os.listdir('txt_files_Yaran'):
    if _file_name.endswith('.txt'):
        texts.append(open('txt_files_Yaran' + '/' + _file_name, 'r', encoding='utf-8').read())
        file_names.append(_file_name)

# %%
d = {'Filename':file_names,'Text':texts}

# %%
paper_df = pd.DataFrame(d)

# %%
paper_df.head()
# Out:
#                                             Filename  \
# 0               Poems by Edna St. Vincent Millay.txt
# 1  Poems by Emily Dickinson, Series One by Emily ...
# 2  Sonnets from the Portuguese by Elizabeth Barre...
# 3           Poems by Christina Georgina Rossetti.txt
#
#                                                 Text
# 0  The Project Gutenberg eBook of Poems\n    \nTh...
# 1  The Project Gutenberg eBook of Poems by Emily ...
# 2  The Project Gutenberg eBook of Sonnets from th...
# 3  The Project Gutenberg eBook of Poems\n    \nTh...

# %%
paper_df['Text'] = paper_df['Text'].str.replace('\s+', ' ', regex=True).str.strip()
paper_df.head()
# Out:
#                                             Filename  \
# 0               Poems by Edna St. Vincent Millay.txt
# 1  Poems by Emily Dickinson, Series One by Emily ...
# 2  Sonnets from the Portuguese by Elizabeth Barre...
# 3           Poems by Christina Georgina Rossetti.txt
#
#                                                 Text
# 0  The Project Gutenberg eBook of Poems This eboo...
# 1  The Project Gutenberg eBook of Poems by Emily ...
# 2  The Project Gutenberg eBook of Sonnets from th...
# 3  The Project Gutenberg eBook of Poems This eboo...

# %%
metadata_df = pd.read_csv('metadata_Yaran.csv')
metadata_df.head()
# Out:
#                                              WORK_ID  \
# 0               Poems by Christina Georgina Rossetti
# 1                   Poems by Edna St. Vincent Millay
# 2  Poems by Emily Dickinson, Series One by Emily ...
# 3  Sonnets from the Portuguese by Elizabeth Barre...
#
#                         AUTHOR AUTHOR'S NATIONALITY  \
# 0  Christina Georgina Rossetti              ENGLAND
# 1      Edna St. Vincent Millay              AMERICA
# 2              Emily Dickinson              AMERICA
# 3   Elizabeth Barrett Browning              ENGLAND
#
#                                   TITLE RELEASE DATE LANGUAGE
# 0                                 Poems     5-Sep-06  English
# 1                                 Poems    31-Mar-19  English
# 2  Poems by Emily Dickinson, Series One     1-Jun-01  English
# 3          Sonnets from the Portuguese      1-Dec-99  English

# %%
paper_df['Filename'] = paper_df['Filename'].str.replace('.txt', '', regex=True)

metadata_df.rename(columns={"WORK_ID": "Filename"}, inplace=True)

print(metadata_df.columns)
print(paper_df.columns)
# Out:
# Index(['Filename', 'AUTHOR', 'AUTHOR'S NATIONALITY', 'TITLE', 'RELEASE DATE',
#        'LANGUAGE'],
#       dtype='object')
# Index(['Filename', 'Text'], dtype='object')

# %%
final_paper_df = metadata_df.merge(paper_df,on='Filename')

# %%
final_paper_df.head()
# Out:
#                                             Filename  \
# 0               Poems by Christina Georgina Rossetti
# 1                   Poems by Edna St. Vincent Millay
# 2  Poems by Emily Dickinson, Series One by Emily ...
# 3  Sonnets from the Portuguese by Elizabeth Barre...
#
#                         AUTHOR AUTHOR'S NATIONALITY  \
# 0  Christina Georgina Rossetti              ENGLAND
# 1      Edna St. Vincent Millay              AMERICA
# 2              Emily Dickinson              AMERICA
# 3   Elizabeth Barrett Browning              ENGLAND
#
#                                   TITLE RELEASE DATE LANGUAGE  \
# 0                                 Poems     5-Sep-06  English
# 1                                 Poems    31-Mar-19  English
# 2  Poems by Emily Dickinson, Series One     1-Jun-01  English
# 3          Sonnets from the Portuguese      1-Dec-99  English
#
#                                                 Text
# 0  The Project Gutenberg eBook of Poems This eboo...
# 1  The Project Gutenberg eBook of Poems This eboo...
# 2  The Project Gutenberg eBook of Poems by Emily ...
# 3  The Project Gutenberg eBook of Sonnets from th...

# %% [markdown]
# ## Text Enrichment with spaCy

# %%
nlp = spacy.load('en_core_web_sm')
print(nlp.pipe_names)
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
def process_text(text):
    return nlp(text)

# %%
final_paper_df['Doc'] = final_paper_df['Text'].apply(process_text)

# %% [markdown]
# ### Text Reduction

# %%
def get_token(doc):
    return [(token.text) for token in doc]

# %%
final_paper_df['Tokens'] = final_paper_df['Doc'].apply(get_token)
final_paper_df.head()
# Out:
#                                             Filename  \
# 0               Poems by Christina Georgina Rossetti
# 1                   Poems by Edna St. Vincent Millay
# 2  Poems by Emily Dickinson, Series One by Emily ...
# 3  Sonnets from the Portuguese by Elizabeth Barre...
#
#                         AUTHOR AUTHOR'S NATIONALITY  \
# 0  Christina Georgina Rossetti              ENGLAND
# 1      Edna St. Vincent Millay              AMERICA
# 2              Emily Dickinson              AMERICA
# 3   Elizabeth Barrett Browning              ENGLAND
#
#                                   TITLE RELEASE DATE LANGUAGE  \
# 0                                 Poems     5-Sep-06  English
# 1                                 Poems    31-Mar-19  English
# 2  Poems by Emily Dickinson, Series One     1-Jun-01  English
# 3          Sonnets from the Portuguese      1-Dec-99  English
#
#                                                 Text  \
# 0  The Project Gutenberg eBook of Poems This eboo...
# 1  The Project Gutenberg eBook of Poems This eboo...
# 2  The Project Gutenberg eBook of Poems by Emily ...
# 3  The Project Gutenberg eBook of Sonnets from th...
#
#                                                  Doc  \
# 0  (The, Project, Gutenberg, eBook, of, Poems, Th...
# 1  (The, Project, Gutenberg, eBook, of, Poems, Th...
# 2  (The, Project, Gutenberg, eBook, of, Poems, by...
# 3  (The, Project, Gutenberg, eBook, of, Sonnets, ...
#
#                                               Tokens
# 0  [The, Project, Gutenberg, eBook, of, Poems, Th...
# 1  [The, Project, Gutenberg, eBook, of, Poems, Th...
# 2  [The, Project, Gutenberg, eBook, of, Poems, by...
# 3  [The, Project, Gutenberg, eBook, of, Sonnets, ...

# %%
tokens = final_paper_df[['Text', 'Tokens']].copy()
tokens.head()
# Out:
#                                                 Text  \
# 0  The Project Gutenberg eBook of Poems This eboo...
# 1  The Project Gutenberg eBook of Poems This eboo...
# 2  The Project Gutenberg eBook of Poems by Emily ...
# 3  The Project Gutenberg eBook of Sonnets from th...
#
#                                               Tokens
# 0  [The, Project, Gutenberg, eBook, of, Poems, Th...
# 1  [The, Project, Gutenberg, eBook, of, Poems, Th...
# 2  [The, Project, Gutenberg, eBook, of, Poems, by...
# 3  [The, Project, Gutenberg, eBook, of, Sonnets, ...

# %% [markdown]
# #### Lemmatization

# %%
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

final_paper_df['Lemmas'] = final_paper_df['Doc'].apply(get_lemma)

# %%
all_lemmas = []
for lemmas in final_paper_df['Lemmas']:
    all_lemmas.extend(lemmas)
    
from collections import Counter

top_100_lemmas_per_doc = []

for i in range(4):
    doc = final_paper_df['Doc'][i]
    lemmas = [token.lemma_ for token in doc]
    lemma_counts = Counter(lemmas)
    top_100_lemmas = lemma_counts.most_common(100)
    top_100_lemmas_per_doc.append(top_20_lemmas)
    print(f"Top 100 lemmas in document {i + 1}:")
    print(top_100_lemmas)
# Out:
# Top 100 lemmas in document 1:
# [(',', 394), ('the', 181), ('and', 153), ('"', 140), ('.', 95), ('a', 91), ('-', 76), ('in', 75), ('her', 71), (':', 70), ('of', 68), ('to', 64), ('she', 60), (';', 57), ('be', 47), ('one', 47), ('with', 45), ('not', 45), ('like', 44), ('I', 39), ('their', 34), ('they', 32), ('for', 31), ('at', 31), ('come', 27), ('Laura', 27), ('buy', 26), ('but', 25), ('Lizzie', 24), ('by', 23), ('fruit', 23), ('goblin', 22), ('no', 21), ('*', 21), ('you', 20), ('or', 20), ('from', 18), ('as', 18), ('my', 17), ('it', 16), ("'s", 16), ('?', 16), ('we', 16), ('man', 16), ('A', 15), ('day', 15), ('that', 15), ('have', 14), ('golden', 14), ('up', 13), ('all', 12), ('on', 12), ('would', 12), ('should', 12), ('kiss', 12), ('cry', 11), ('down', 11), ('night', 11), ('this', 10), ('an', 10), ('Song', 10), ('when', 10), ('life', 10), ('say', 10), ('hear', 10), ('look', 10), ('if', 9), ('will', 9), ('head', 9), ('our', 9), ('glen', 9), ('then', 9), ('out', 8), ('heart', 8), ('do', 8), ('never', 8), ('must', 8), ('so', 8), ('more', 8), ('eat', 8), ('other', 7), ('home', 7), ('after', 7), ('what', 7), ('go', 7), ('eye', 7), ('sister', 7), ('full', 7), ('close', 7), ('brook', 7), ('such', 7), ('long', 7), ('suck', 7), ('water', 7), ('first', 7), ('he', 6), ('your', 6), ('mouth', 6), ('lip', 6), ('grow', 6)]
# Top 100 lemmas in document 2:
# [(',', 490), ('the', 306), ('and', 300), ('I', 241), ('be', 157), ('a', 146), ('my', 125), ('.', 109), ('to', 96), ('of', 94), ('!', 89), (';', 81), ('-', 76), ('in', 75), ('_', 74), ('that', 63), ('all', 60), ('not', 58), ('you', 50), ('but', 49), ('she', 48), ('have', 42), ('for', 37), ('at', 36), ('with', 36), ('it', 33), ('from', 33), ('on', 33), ('no', 32), ('as', 32), ('so', 31), ('will', 30), ('"', 30), ('’s', 29), ('he', 27), ('this', 26), ('go', 25), ('there', 23), ('can', 23), ('her', 23), ('by', 22), ('--', 22), ('see', 22), ('what', 22), ('or', 21), ('do', 20), ('we', 20), ('little', 19), ('up', 18), ('long', 18), ('come', 18), ('know', 18), ('would', 18), ('?', 18), ('his', 17), ('could', 17), ('look', 17), ('thing', 17), ('sky', 17), ('love', 16), ('eye', 16), ('say', 16), ('like', 16), ('if', 15), ('when', 15), ('through', 15), ('never', 15), (':', 14), ('one', 14), ('back', 14), ('’', 14), ('heart', 14), ('day', 14), ('where', 13), ('grow', 13), ('should', 13), ('more', 13), ('way', 13), ('they', 13), ('hand', 13), ('man', 13), ('mine', 12), ('such', 12), ('rain', 12), ('any', 12), ('make', 11), ('oh', 11), ('upon', 11), ('down', 11), ('hear', 11), ('how', 11), ('every', 11), ('who', 11), ('face', 11), ('leave', 11), ('world', 10), ('shall', 10), ('stand', 10), ('till', 10), ('over', 10)]
# Top 100 lemmas in document 3:
# [(',', 365), ('the', 191), ('.', 162), ('be', 106), ('and', 89), ('I', 87), ('of', 77), ('a', 69), ('to', 63), ('!', 62), ('that', 50), (';', 50), ('in', 37), ('you', 31), ('have', 29), ('--', 27), ('it', 26), ('but', 26), ('not', 24), ('as', 24), ('my', 23), ('for', 22), ('with', 21), ('?', 21), ("'s", 20), ('this', 19), ('if', 19), ('by', 18), ('so', 18), ('no', 17), ('there', 17), ('when', 17), ('or', 16), ('can', 16), ('time', 15), (':', 14), ('"', 14), ('one', 14), ('life', 14), ('he', 13), ('they', 13), ('then', 13), ('his', 13), ('we', 13), ('would', 13), ('at', 12), ('all', 12), ("'", 12), ('could', 12), ('little', 12), ('her', 11), ('love', 11), ('on', 11), ('what', 11), ('other', 10), ('will', 10), ('day', 10), ('t', 10), ('know', 10), ('go', 10), ('where', 9), ('she', 9), ('some', 9), ('just', 9), ('an', 9), ('thee', 9), ('come', 9), ('from', 9), ('-', 8), ('our', 8), ('sea', 8), ('do', 8), ('eye', 8), ('your', 8), ('flower', 8), ('who', 7), ('such', 7), ('upon', 7), ('down', 7), ('how', 7), ('till', 7), ('more', 7), ('out', 7), ('new', 7), ('*', 6), ('tell', 6), ('see', 6), ('their', 6), ('door', 6), ('pain', 6), ('within', 6), ('too', 6), ('its', 6), ('old', 6), ('without', 6), ('like', 6), ('look', 6), ('mine', 6), ('use', 5), ('away', 5)]
# Top 100 lemmas in document 4:
# [(',', 402), ('I', 170), ('the', 167), ('.', 144), ('and', 140), ('of', 92), ('to', 86), ('my', 78), ('be', 73), ('in', 65), ('a', 62), ('love', 61), ('as', 48), ('!', 44), ('thy', 44), ('thee', 43), ('for', 42), ('that', 41), ('on', 36), ('-', 35), ("'s", 34), ('thou', 34), ('from', 32), ('with', 32), ('it', 31), ('all', 29), ('this', 28), ('not', 28), ('?', 27), ('so', 22), ('who', 22), ('we', 20), ('can', 20), ('have', 19), ('heart', 19), ('yet', 18), ('do', 18), ('at', 17), ('or', 17), ('if', 17), ('God', 17), ('let', 17), ('when', 17), ('see', 16), ('thine', 16), (';', 16), ('--', 16), ('think', 15), ('which', 15), ('Beloved', 15), (':', 14), ('by', 14), ('but', 14), ('up', 14), ('what', 14), ('soul', 14), ('give', 13), ('their', 13), ('"', 13), ('say', 12), ('they', 12), ('life', 12), ('look', 12), ('out', 12), ('world', 11), ('o', 11), ('our', 11), ('own', 11), ('year', 11), ('mine', 11), ('no', 10), ('how', 10), ('only', 10), ('Thou', 10), ('lift', 10), ('stand', 10), ('here', 10), ('through', 10), ('hear', 10), ('will', 9), ('hast', 9), ('face', 9), ('because', 9), ('tear', 9), ('hand', 9), ('most', 8), ('once', 8), ('its', 8), ('two', 8), ('word', 8), ('should', 8), ('nor', 8), ('eye', 8), ('these', 8), ('too', 8), ('use', 7), ('where', 7), ('shall', 7), ('change', 7), ('into', 7)]

# %% [markdown]
# #### summary
# Document 1:
#
# The higher frequency of commas, articles, conjunctions, and punctuation marks (such as double quotation marks, periods) may indicate that the author pays more attention to the flow of the storyline and the connection between sentences. The presence of female characters is emphasized, with names such as "Laura" and "Lizzie" appearing frequently, which may reflect the important role women play in the poem.
# Words about feelings and relationships appear frequently, possibly referring to feelings between women, friendships, or sisterhood.
#
# Document 2:
# Commas, articles, conjunctions, and punctuation marks also appear frequently, and attention is also paid to the connectivity of sentences.
# A high frequency of words related to personal pronouns (e.g., “I,” “you,” “she”) may indicate that the poem focuses more on the personal emotions and experiences of the author, reader, or other characters.
#
#
# Document 3:
#
# Commas and punctuation marks appear more frequently, but articles and conjunctions appear less frequently.
# Time-related words such as "time", as well as pronouns and exclamation points are used more frequently, which may point to thinking or reflection on time, emotion and life.
#
# Document 4:
# Highlights the expression of love and emotion. The frequent occurrence of words such as "love", "soul" and "heart" reflects the author's strong focus on emotions and inner experience.

# %%
print(f'"love" appears in the text tokens column ' + str(final_paper_df['Tokens'].apply(lambda x: x.count('love')).sum()) + ' times.')
print(f'"love" appears in the lemmas column ' + str(final_paper_df['Lemmas'].apply(lambda x: x.count('love')).sum()) + ' times.')
# Out:
# "love" appears in the text tokens column 75 times.
# "love" appears in the lemmas column 91 times.

# %%
def get_pos(doc):
    return [(token.pos_, token.tag_) for token in doc]

final_paper_df['POS'] = final_paper_df['Doc'].apply(get_pos)

# %%
list(final_paper_df['POS'])
# Out:
# [[('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNPS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('X', 'XX'),
#   ('VERB', 'VB'),
#   ('SYM', '$'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('INTJ', 'UH'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PUNCT', '-RRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('NUM', 'CD'),
#   ('PUNCT', '.'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PUNCT', 'NFP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBZ'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', '.'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('INTJ', 'UH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNPS'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('PUNCT', '``'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNPS'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', '``'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('VERB', 'VBN'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBG'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJS'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'DT'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ':'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', 'HYPH'),
#   ('VERB', 'VBG'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', '``'),
#   ('ADV', 'RB'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'WP'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNPS'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNPS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('X', 'FW'),
#   ('X', 'FW'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('SCONJ', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PART', 'RB'),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '``'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', "''"),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('VERB', 'VBG'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'WRB'),
#   ('PUNCT', '.'),
#   ('PUNCT', '``'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PRON', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', "''"),
#   ('PRON', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '``'),
#   ('PRON', 'EX'),
#   ('VERB', 'VBZ'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ...],
#  [('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNPS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('NOUN', 'NNS'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('X', 'XX'),
#   ('VERB', 'VB'),
#   ('SYM', '$'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-LRB-'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SYM', 'SYM'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('INTJ', 'UH'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-LRB-'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('SYM', 'SYM'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'NFP'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', 'NFP'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-LRB-'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '-RRB-'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PUNCT', 'NFP'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('PUNCT', 'NFP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PART', 'RB'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PART', 'RB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('SCONJ', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'HYPH'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNPS'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('NUM', 'CD'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('NUM', 'CD'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'DT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('AUX', 'VBD'),
#   ('NUM', 'CD'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', ':'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'WDT'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ':'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('AUX', 'MD'),
#   ('ADV', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ':'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('AUX', 'VBZ'),
#   ('PART', 'RB'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJS'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBG'),
#   ('ADP', 'RP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ':'),
#   ('NUM', 'CD'),
#   ('VERB', 'VBD'),
#   ('ADP', 'RP'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBN'),
#   ('ADP', 'RP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VB'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('DET', 'WP$'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('DET', 'DT'),
#   ('SCONJ', 'WRB'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'WRB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBG'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('AUX', 'MD'),
#   ...],
#  [('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNPS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'NN'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('PRON', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('PART', 'RB'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('X', 'XX'),
#   ('VERB', 'VB'),
#   ('SYM', '$'),
#   ('NUM', 'CD'),
#   ('PUNCT', '-RRB-'),
#   ('ADV', 'RBS'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('NUM', 'CD'),
#   ('PUNCT', ','),
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('X', 'ADD'),
#   ('X', 'ADD'),
#   ('X', 'XX'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'WDT'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PUNCT', ':'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('SCONJ', 'IN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PUNCT', ':'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-LRB-'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PUNCT', '``'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PUNCT', "''"),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', '-RRB-'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'DT'),
#   ('PRON', 'WP'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '.'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PART', 'RB'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('VERB', 'VBG'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('DET', 'WP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('X', 'LS'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PUNCT', ':'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('ADP', 'IN'),
#   ('ADV', 'RB'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NNS'),
#   ('PART', 'POS'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ':'),
#   ('VERB', 'VBZ'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PUNCT', '``'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', "''"),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('DET', 'WDT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PUNCT', '.'),
#   ('INTJ', 'UH'),
#   ('PUNCT', '.'),
#   ('INTJ', 'UH'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJS'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJS'),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'NN'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ','),
#   ('PUNCT', ':'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VBZ'),
#   ('SCONJ', 'IN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VB'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
# ...
#   ('NUM', 'CD'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBZ'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PUNCT', 'NFP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'WRB'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBG'),
#   ('PRON', 'DT'),
#   ('VERB', 'VBG'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'RP'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'WP'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'WP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJ'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'IN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VB'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PART', 'RB'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'WDT'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'DT'),
#   ('ADJ', 'JJS'),
#   ('SCONJ', 'IN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'RP'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP$'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADP', 'RP'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBZ'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('PUNCT', '.'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADV', 'RB'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PRON', 'WP'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('ADV', 'RBS'),
#   ('PUNCT', '.'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBZ'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'WDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'WRB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PROPN', 'NNP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('VERB', 'VBN'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'DT'),
#   ('VERB', 'VBP'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('CCONJ', 'CC'),
#   ('NOUN', 'NNS'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('INTJ', 'UH'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PRON', 'DT'),
#   ('PRON', 'WP'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('ADJ', 'JJ'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('SCONJ', 'WRB'),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PRON', 'PRP'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('ADV', 'RB'),
#   ('SCONJ', 'WRB'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBN'),
#   ('PUNCT', 'HYPH'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'WP'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBZ'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('CCONJ', 'CC'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ':'),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('PRON', 'DT'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'WP'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('PUNCT', '``'),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('SCONJ', 'WRB'),
#   ('DET', 'DT'),
#   ('ADJ', 'JJ'),
#   ('PROPN', 'NNP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('PRON', 'PRP'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ':'),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('VERB', 'VBD'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('PUNCT', '``'),
#   ('VERB', 'VB'),
#   ('ADV', 'RB'),
#   ('PRON', 'WP'),
#   ('VERB', 'VBZ'),
#   ('PRON', 'DT'),
#   ('PUNCT', ','),
#   ('PUNCT', "''"),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBD'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ','),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PUNCT', '``'),
#   ('PART', 'RB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', '.'),
#   ('PUNCT', "''"),
#   ('PROPN', 'NNP'),
#   ('CCONJ', 'CC'),
#   ('ADV', 'RB'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('PROPN', 'NNP'),
#   ('PART', 'POS'),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBP'),
#   ('VERB', 'VBN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBG'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('NUM', 'CD'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('PUNCT', '.'),
#   ('PUNCT', '.'),
#   ('PUNCT', '.'),
#   ('PRON', 'DT'),
#   ('AUX', 'VBD'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('PUNCT', '.'),
#   ('PUNCT', '.'),
#   ('PUNCT', '.'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VBD'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADV', 'RB'),
#   ('ADV', 'RB'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('SCONJ', 'IN'),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('AUX', 'VBD'),
#   ('VERB', 'VBN'),
#   ('PUNCT', ','),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('VERB', 'VBN'),
#   ('ADV', 'RB'),
#   ('PUNCT', ','),
#   ('AUX', 'MD'),
#   ('AUX', 'VB'),
#   ('VERB', 'VBN'),
#   ('ADJ', 'JJR'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PUNCT', '``'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', "''"),
#   ('AUX', 'VBZ'),
#   ('ADJ', 'JJR'),
#   ('ADP', 'IN'),
#   ('PROPN', 'NNP'),
#   ('ADP', 'IN'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'MD'),
#   ('PART', 'RB'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('CCONJ', 'CC'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('PUNCT', ':'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('ADP', 'IN'),
#   ('DET', 'PDT'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', 'HYPH'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ':'),
#   ('CCONJ', 'CC'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('AUX', 'VBG'),
#   ('VERB', 'VBN'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('PUNCT', ','),
#   ('PRON', 'PRP'),
#   ('AUX', 'MD'),
#   ('CCONJ', 'CC'),
#   ('VERB', 'VB'),
#   ('PRON', 'DT'),
#   ('ADV', 'RBR'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('NUM', 'CD'),
#   ('ADJ', 'JJ'),
#   ('AUX', 'VBP'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('ADJ', 'JJ'),
#   ('PUNCT', ','),
#   ('INTJ', 'UH'),
#   ('ADV', 'RB'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('ADP', 'IN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('CCONJ', 'CC'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', '.'),
#   ('PRON', 'PRP$'),
#   ('VERB', 'VBG'),
#   ('NUM', 'CD'),
#   ('NOUN', 'NNS'),
#   ('VERB', 'VBP'),
#   ('ADJ', 'JJ'),
#   ('ADP', 'IN'),
#   ('NUM', 'CD'),
#   ('DET', 'DT'),
#   ('PUNCT', ','),
#   ('SCONJ', 'IN'),
#   ('PRON', 'PRP'),
#   ('VERB', 'VBP'),
#   ('NOUN', 'NN'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('VERB', 'VBG'),
#   ('PUNCT', '.'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('VERB', 'VBP'),
#   ('PROPN', 'NNP'),
#   ('PUNCT', ','),
#   ('NOUN', 'NN'),
#   ('DET', 'DT'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NNS'),
#   ('PUNCT', ','),
#   ('ADP', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADP', 'IN'),
#   ('DET', 'DT'),
#   ('NUM', 'CD'),
#   ('ADJ', 'JJR'),
#   ('NOUN', 'NNS'),
#   ('SCONJ', 'IN'),
#   ('NOUN', 'NNS'),
#   ('ADV', 'RB'),
#   ('AUX', 'MD'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP'),
#   ('PUNCT', ','),
#   ('PART', 'TO'),
#   ('VERB', 'VB'),
#   ('PRON', 'PRP$'),
#   ('NOUN', 'NN'),
#   ('ADP', 'IN'),
#   ('ADJ', 'JJ'),
#   ('NOUN', 'NN'),
#   ('PUNCT', '.'),
#   ('PRON', 'WP'),
#   ('NOUN', 'NN'),
#   ...]]

# %%
spacy.explain("IN")
# Out:
# 'conjunction, subordinating or preposition'

# %%
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

final_paper_df['Proper_Nouns'] = final_paper_df['Doc'].apply(extract_proper_nouns)

# %%
list(final_paper_df.loc[[1, 1], 'Proper_Nouns'])
# Out:
# [['Project',
#   'Gutenberg',
#   'eBook',
#   'Poems',
#   'United',
#   'States',
#   'Project',
#   'Gutenberg',
#   'License',
#   'United',
#   'States',
#   'eBook',
#   'Edna',
#   'St.',
#   'Vincent',
#   'Millay',
#   'Release',
#   'March',
#   'English',
#   'Tim',
#   'Lindell',
#   'Charlie',
#   'Howard',
#   'Online',
#   'Proofreading',
#   'Team',
#   'Internet',
#   'Archive',
#   'Canadian',
#   'Libraries',
#   'PROJECT',
#   'GUTENBERG',
#   'Tim',
#   'Lindell',
#   'Charlie',
#   'Howard',
#   'Online',
#   'Proofreading',
#   'Team',
#   'Internet',
#   'Archive',
#   'Canadian',
#   'Libraries',
#   '_',
#   'Edna',
#   'St.',
#   'Vincent',
#   'Millay',
#   'Poems',
#   '_',
#   'Edna',
#   'St.',
#   'Vincent',
#   'Millay',
#   'London',
#   'Martin',
#   'Secker',
#   'Great',
#   'Britain',
#   'London',
#   'Martin',
#   'Secker',
#   'Ltd.',
#   '_',
#   'Renascence',
#   'God',
#   'World',
#   'Afternoon',
#   'Hill',
#   'Journey',
#   'Sorrow',
#   'Tavern',
#   'Life',
#   'Little',
#   'Ghost',
#   'Kin',
#   'Sorrow',
#   'Songs',
#   'Shattering',
#   'Shroud',
#   'Dream',
#   'Indifference',
#   'Witch',
#   'Blight',
#   'Year',
#   'Old',
#   'Sonnets',
#   'v',
#   'Sonnet',
#   'vi',
#   'Bluebeard',
#   'II',
#   'Recuerdo',
#   'Thursday',
#   'Impossible',
#   'Him',
#   'Singing',
#   'Woman',
#   'Wood',
#   'Edge',
#   'Humoresque',
#   'Overheard',
#   'Singing',
#   'Unexplorer',
#   'Penitent',
#   'Daphne',
#   'Portrait',
#   'Neighbour',
#   'Merry',
#   'Maid',
#   'S.',
#   'M.',
#   'Philosopher',
#   'Love',
#   'Spring',
#   'City',
#   'Trees',
#   'Blue',
#   'Flag',
#   'Bog',
#   'Eel',
#   'Grass',
#   'Elegy',
#   'Bean',
#   'Stalk',
#   'Passer',
#   'Mortuus',
#   'Est',
#   'Pastoral',
#   'Assault',
#   'Low',
#   'Tide',
#   'Song',
#   'Second',
#   'April',
#   'Poet',
#   'Book',
#   'Alms',
#   'Inland',
#   'Died',
#   'Young',
#   'Wraith',
#   'Ebb',
#   'Elaine',
#   'Burial',
#   'Mariposa',
#   'Oberon',
#   'Lament',
#   'Exiled',
#   'Death',
#   'Autumn',
#   'Ode',
#   'Silence',
#   'Memorial',
#   'D.',
#   'C.',
#   'Unnamed',
#   'Sonnets',
#   'i',
#   'xii',
#   'Wild',
#   'Swans',
#   'enough!--I',
#   'Undefined',
#   'Immensity',
#   'Eternity',
#   'Universe',
#   'Lay',
#   'out.--Ah',
#   'Mine',
#   'desire,--',
#   'each,--then',
#   'Capri',
#   'great',
#   'fog',
#   'bank',
#   'heavens',
#   'I.',
#   'Mine',
#   'God',
#   'Gave',
#   'more,--there',
#   'Cool',
#   'Shakes',
#   'Rolls',
#   'silver',
#   'God',
#   'smell,--',
#   'God',
#   'Thy',
#   'Thee',
#   'Thee',
#   'Thy',
#   'God',
#   'Thy',
#   'sky,--',
#   'God',
#   'East',
#   'West',
#   'God',
#   'World',
#   'Thy',
#   'Thy',
#   'ache',
#   'sag',
#   'World',
#   'World',
#   'stretcheth',
#   'Thou’st',
#   'me,--let',
#   'Hill',
#   'Journey',
#   '_',
#   'Blow',
#   'me,--I',
#   'Care',
#   'Cat',
#   'Dim',
#   'fern',
#   'ere',
#   'day,--sharp',
#   'blue',
#   'hill',
#   'silver',
#   'lake',
#   'pain,--',
#   'Dawn',
#   'hill',
#   'fancy--',
#   'Life',
#   'Love',
#   'through,--',
#   'me,--and',
#   'mouse,--',
#   'Little',
#   'Ghost',
#   'most--',
#   'green',
#   'gate',
#   'ivy',
#   'Kin',
#   'Sorrow',
#   'Sorrow',
#   'Sorrow',
#   'Sorrow--',
#   'Sorrow',
#   'kin',
#   '_',
#   'Songs',
#   'Shattering',
#   'Budded',
#   'II',
#   'tis',
#   'spring;--',
#   'Spring',
#   'Ere',
#   '!',
#   'Blossom',
#   'Shroud',
#   'Dream',
#   'waking,--',
#   'White',
#   'loose,--it',
#   'Swung',
#   'matter,--',
#   'Ah',
#   'Love',
#   'O',
#   'Love',
#   'come,--',
#   'Love',
#   'dawn,--',
#   'Witch',
#   'Wife',
#   'grown,--',
#   'Rough',
#   'slept,--I',
#   'Ye',
#   'pitiful,--',
#   'Endures',
#   'Year',
#   'Old',
#   'October',
#   'October',
#   'Thou',
#   'lilacs,--no',
#   'thou',
#   'Thy',
#   'thee',
#   'mist,--with',
#   'Time',
#   'go,--so',
#   'view,--',
#   'IV',
#   'mirth',
#   'again--',
#   'Aloud',
#   'VI',
#   'Bluebeard',
#   'II',
#   'Recuerdo',
#   'stable--',
#   'God',
#   'Thursday',
#   'Wednesday',
#   'Impossible',
#   'Cairo',
#   'Cathay',
#   'Carthaginian',
#   'Singing',
#   'Woman',
#   'Wood',
#   'god',
#   'bush',
#   'Aves',
#   'Credos',
#   'Psalms',
#   'Psalter',
#   'Vesper',
#   'Matin',
#   'Greek',
#   'Latin',
#   'Heaven',
#   'Love',
#   'Grant',
#   'lover',
#   'Overheard',
#   'Singing',
#   'Prue',
#   'Joan',
#   'Agatha',
#   'hug',
#   'hearth,--',
#   'Mig',
#   'Sue',
#   'of,--',
#   'Sue',
#   'Prue',
#   'Agatha',
#   'Mig',
#   'Joan',
#   'Prue',
#   'Mine',
#   'Agatha',
#   'hug',
#   'Sue',
#   'jell--',
#   'Mig',
#   'Joan',
#   'choice,--',
#   'voice,--',
#   'Agatha',
#   'Mig',
#   'Sue',
#   'Joan',
#   'Prue',
#   'Prue',
#   'Mig',
#   'Sue',
#   'Joan',
#   'Agatha',
#   'hug',
#   'hearth,--',
#   'Unexplorer',
#   'Grown',
#   'Penitent',
#   'Sorrow',
#   'Little',
#   'Sorrow',
#   'God',
#   'planning--',
#   'Little',
#   'Sorrow',
#   'sleep--',
#   'off;--to',
#   'Apollo',
#   'Portrait',
#   'Neighbour',
#   'Queen',
#   'Anne'],
#  ['Project',
#   'Gutenberg',
#   'eBook',
#   'Poems',
#   'United',
#   'States',
#   'Project',
#   'Gutenberg',
#   'License',
#   'United',
#   'States',
#   'eBook',
#   'Edna',
#   'St.',
#   'Vincent',
#   'Millay',
#   'Release',
#   'March',
#   'English',
#   'Tim',
#   'Lindell',
#   'Charlie',
#   'Howard',
#   'Online',
#   'Proofreading',
#   'Team',
#   'Internet',
#   'Archive',
#   'Canadian',
#   'Libraries',
#   'PROJECT',
#   'GUTENBERG',
#   'Tim',
#   'Lindell',
#   'Charlie',
#   'Howard',
#   'Online',
#   'Proofreading',
#   'Team',
#   'Internet',
#   'Archive',
#   'Canadian',
#   'Libraries',
#   '_',
#   'Edna',
#   'St.',
#   'Vincent',
#   'Millay',
#   'Poems',
#   '_',
#   'Edna',
#   'St.',
#   'Vincent',
#   'Millay',
#   'London',
#   'Martin',
#   'Secker',
#   'Great',
#   'Britain',
#   'London',
#   'Martin',
#   'Secker',
#   'Ltd.',
#   '_',
#   'Renascence',
#   'God',
#   'World',
#   'Afternoon',
#   'Hill',
#   'Journey',
#   'Sorrow',
#   'Tavern',
#   'Life',
#   'Little',
#   'Ghost',
#   'Kin',
#   'Sorrow',
#   'Songs',
#   'Shattering',
#   'Shroud',
#   'Dream',
#   'Indifference',
#   'Witch',
#   'Blight',
#   'Year',
#   'Old',
#   'Sonnets',
#   'v',
#   'Sonnet',
#   'vi',
#   'Bluebeard',
#   'II',
#   'Recuerdo',
#   'Thursday',
#   'Impossible',
#   'Him',
#   'Singing',
#   'Woman',
#   'Wood',
#   'Edge',
#   'Humoresque',
#   'Overheard',
#   'Singing',
#   'Unexplorer',
#   'Penitent',
#   'Daphne',
#   'Portrait',
#   'Neighbour',
#   'Merry',
#   'Maid',
#   'S.',
#   'M.',
#   'Philosopher',
#   'Love',
#   'Spring',
#   'City',
#   'Trees',
#   'Blue',
#   'Flag',
#   'Bog',
#   'Eel',
#   'Grass',
#   'Elegy',
#   'Bean',
#   'Stalk',
#   'Passer',
#   'Mortuus',
#   'Est',
#   'Pastoral',
#   'Assault',
#   'Low',
#   'Tide',
#   'Song',
#   'Second',
#   'April',
#   'Poet',
#   'Book',
#   'Alms',
#   'Inland',
#   'Died',
#   'Young',
#   'Wraith',
#   'Ebb',
#   'Elaine',
#   'Burial',
#   'Mariposa',
#   'Oberon',
#   'Lament',
#   'Exiled',
#   'Death',
#   'Autumn',
#   'Ode',
#   'Silence',
#   'Memorial',
#   'D.',
#   'C.',
#   'Unnamed',
#   'Sonnets',
#   'i',
#   'xii',
#   'Wild',
#   'Swans',
#   'enough!--I',
#   'Undefined',
#   'Immensity',
#   'Eternity',
#   'Universe',
#   'Lay',
#   'out.--Ah',
#   'Mine',
#   'desire,--',
#   'each,--then',
#   'Capri',
#   'great',
#   'fog',
#   'bank',
#   'heavens',
#   'I.',
#   'Mine',
#   'God',
#   'Gave',
#   'more,--there',
#   'Cool',
#   'Shakes',
#   'Rolls',
#   'silver',
#   'God',
#   'smell,--',
#   'God',
#   'Thy',
#   'Thee',
#   'Thee',
#   'Thy',
#   'God',
#   'Thy',
#   'sky,--',
#   'God',
#   'East',
#   'West',
#   'God',
#   'World',
#   'Thy',
#   'Thy',
#   'ache',
#   'sag',
#   'World',
#   'World',
#   'stretcheth',
#   'Thou’st',
#   'me,--let',
#   'Hill',
#   'Journey',
#   '_',
#   'Blow',
#   'me,--I',
#   'Care',
#   'Cat',
#   'Dim',
#   'fern',
#   'ere',
#   'day,--sharp',
#   'blue',
#   'hill',
#   'silver',
#   'lake',
#   'pain,--',
#   'Dawn',
#   'hill',
#   'fancy--',
#   'Life',
#   'Love',
#   'through,--',
#   'me,--and',
#   'mouse,--',
#   'Little',
#   'Ghost',
#   'most--',
#   'green',
#   'gate',
#   'ivy',
#   'Kin',
#   'Sorrow',
#   'Sorrow',
#   'Sorrow',
#   'Sorrow--',
#   'Sorrow',
#   'kin',
#   '_',
#   'Songs',
#   'Shattering',
#   'Budded',
#   'II',
#   'tis',
#   'spring;--',
#   'Spring',
#   'Ere',
#   '!',
#   'Blossom',
#   'Shroud',
#   'Dream',
#   'waking,--',
#   'White',
#   'loose,--it',
#   'Swung',
#   'matter,--',
#   'Ah',
#   'Love',
#   'O',
#   'Love',
#   'come,--',
#   'Love',
#   'dawn,--',
#   'Witch',
#   'Wife',
#   'grown,--',
#   'Rough',
#   'slept,--I',
#   'Ye',
#   'pitiful,--',
#   'Endures',
#   'Year',
#   'Old',
#   'October',
#   'October',
#   'Thou',
#   'lilacs,--no',
#   'thou',
#   'Thy',
#   'thee',
#   'mist,--with',
#   'Time',
#   'go,--so',
#   'view,--',
#   'IV',
#   'mirth',
#   'again--',
#   'Aloud',
#   'VI',
#   'Bluebeard',
#   'II',
#   'Recuerdo',
#   'stable--',
#   'God',
#   'Thursday',
#   'Wednesday',
#   'Impossible',
#   'Cairo',
#   'Cathay',
#   'Carthaginian',
#   'Singing',
#   'Woman',
#   'Wood',
#   'god',
#   'bush',
#   'Aves',
#   'Credos',
#   'Psalms',
#   'Psalter',
#   'Vesper',
#   'Matin',
#   'Greek',
#   'Latin',
#   'Heaven',
#   'Love',
#   'Grant',
#   'lover',
#   'Overheard',
#   'Singing',
#   'Prue',
#   'Joan',
#   'Agatha',
#   'hug',
#   'hearth,--',
#   'Mig',
#   'Sue',
#   'of,--',
#   'Sue',
#   'Prue',
#   'Agatha',
#   'Mig',
#   'Joan',
#   'Prue',
#   'Mine',
#   'Agatha',
#   'hug',
#   'Sue',
#   'jell--',
#   'Mig',
#   'Joan',
#   'choice,--',
#   'voice,--',
#   'Agatha',
#   'Mig',
#   'Sue',
#   'Joan',
#   'Prue',
#   'Prue',
#   'Mig',
#   'Sue',
#   'Joan',
#   'Agatha',
#   'hug',
#   'hearth,--',
#   'Unexplorer',
#   'Grown',
#   'Penitent',
#   'Sorrow',
#   'Little',
#   'Sorrow',
#   'God',
#   'planning--',
#   'Little',
#   'Sorrow',
#   'sleep--',
#   'off;--to',
#   'Apollo',
#   'Portrait',
#   'Neighbour',
#   'Queen',
#   'Anne']]

# %% [markdown]
# #### Named Entity Recognition

# %%
labels = nlp.get_pipe("ner").labels

for label in labels:
    print(label + ' : ' + spacy.explain(label))
# Out:
# CARDINAL : Numerals that do not fall under another type
# DATE : Absolute or relative dates or periods
# EVENT : Named hurricanes, battles, wars, sports events, etc.
# FAC : Buildings, airports, highways, bridges, etc.
# GPE : Countries, cities, states
# LANGUAGE : Any named language
# LAW : Named documents made into laws.
# LOC : Non-GPE locations, mountain ranges, bodies of water
# MONEY : Monetary values, including unit
# NORP : Nationalities or religious or political groups
# ORDINAL : "first", "second", etc.
# ORG : Companies, agencies, institutions, etc.
# PERCENT : Percentage, including "%"
# PERSON : People, including fictional
# PRODUCT : Objects, vehicles, foods, etc. (not services)
# QUANTITY : Measurements, as of weight or distance
# TIME : Times smaller than a day
# WORK_OF_ART : Titles of books, songs, etc.

# %%
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]
final_paper_df['Named_Entities'] = final_paper_df['Doc'].apply(extract_named_entities)
final_paper_df['Named_Entities']
# Out:
# 0    [GPE, ORG, GPE, PRODUCT, PERSON, DATE, LAW, PE...
# 1    [GPE, ORG, GPE, PRODUCT, DATE, LAW, PERSON, PE...
# 2    [GPE, ORG, GPE, PRODUCT, PERSON, PERSON, PERSO...
# 3    [NORP, GPE, ORG, GPE, PRODUCT, NORP, PERSON, D...
# Name: Named_Entities, dtype: object

# %%
def extract_named_entities(doc):
    return [ent for ent in doc.ents]

final_paper_df['NE_Words'] = final_paper_df['Doc'].apply(extract_named_entities)
final_paper_df['NE_Words']
# Out:
# 0    [(the, United, States), (the, Project, Gutenbe...
# 1    [(the, United, States), (the, Project, Gutenbe...
# 2    [(the, United, States), (the, Project, Gutenbe...
# 3    [(Portuguese), (the, United, States), (the, Pr...
# Name: NE_Words, dtype: object

# %%
doc = final_paper_df['Doc'][2]

displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The Project Gutenberg eBook of Poems by Emily Dickinson, Series One This ebook is for the use of anyone anywhere in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and most other parts of the world at no cost and with almost no restrictions whatsoever. You may copy it, give it away or re-use it under the terms of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Project Gutenberg License
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  included with this ebook or online at www.gutenberg.org. If you are not located in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , you will have to check the laws of the country where you are located before using this
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . Title: Poems by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Emily Dickinson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Series One Author: Emily
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dickinson
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Editor:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thomas Wentworth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  Higginson Mabel Loomis
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Todd Release
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  date:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 1, 2001
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  [
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eBook #2678
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
# ] Most recently updated:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 17, 2020 Language:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  English *** START OF THE PROJECT GUTENBERG EBOOK POEMS BY EMILY DICKINSON, SERIES ONE *** Etext scanned by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jim Tinsley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  &lt;jtinsley@pobox.com&gt; POEMS by EMILY DICKINSON Series
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Edited by
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of her friends MABEL LOOMIS TODD and T.W.HIGGINSON This is my letter to the world, That never wrote to me, -- The simple news that
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nature
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  told, With tender majesty. Her message is committed To hands I cannot see; For love of her, sweet countrymen, Judge tenderly of me!
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     I. LIFE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     I. SUCCESS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . [Published in &quot;A Masque of Poets&quot; at the request of &quot;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     H.H.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,&quot; the author's fellow-townswoman and friend.]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Success
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is counted sweetest By those who ne'er succeed. To comprehend a nectar
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Requires
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  sorest need. Not one of all the purple host Who took the flag to-day Can tell the definition, So clear, of victory, As he, defeated, dying, On whose forbidden ear The distant strains of triumph
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Break
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , agonized and clear! II. Our share of
# <mark class="entity" style="ba

# %% [markdown]
# ### Download Enriched Dataset

# %%
final_paper_df.to_csv('Yaran_MICUSP_papers_with_spaCy_tags.csv')

# %% [markdown]
# ## Analysis of Linguistic Annotations

# %% [markdown]
# ### Part of Speech Analysis

# %%
doc = nlp("This is 'an' example? sentence")

print(doc.count_by(spacy.attrs.POS))
# Out:
# {95: 1, 87: 1, 97: 3, 90: 1, 92: 2}

# %%
num_pos = doc.count_by(spacy.attrs.POS)

dictionary = {}
for k,v in sorted(num_pos.items()):
  dictionary[doc.vocab[k].text] = v

dictionary
# Out:
# {'AUX': 1, 'DET': 1, 'NOUN': 2, 'PRON': 1, 'PUNCT': 3}

# %%
pos_analysis_df = final_paper_df[['Filename','Doc']]

num_list = []

def get_pos_tags(doc):
    dictionary = {}
    num_pos = doc.count_by(spacy.attrs.POS)
    for k,v in sorted(num_pos.items()):
        dictionary[doc.vocab[k].text] = v
    num_list.append(dictionary)

pos_analysis_df.loc['C_POS'] = pos_analysis_df['Doc'].apply(get_pos_tags)

# %%
pos_counts = pd.DataFrame(num_list)
columns = list(pos_counts.columns)
idx = 0
new_col = pos_analysis_df['Doc']
pos_counts.insert(loc=idx, column='Doc', value=new_col)

pos_counts
# Out:
#                                                  Doc  ADJ  ADP  ADV  AUX  \
# 0  (The, Project, Gutenberg, eBook, of, Poems, Th...  270  445  128  110
# 1  (The, Project, Gutenberg, eBook, of, Poems, Th...  371  567  261  338
# 2  (The, Project, Gutenberg, eBook, of, Poems, by...  214  294  157  193
# 3  (The, Project, Gutenberg, eBook, of, Sonnets, ...  304  478  243  163
#
#    CCONJ  DET  INTJ  NOUN  NUM  PART  PRON  PROPN  PUNCT  SCONJ  SYM  VERB  X
# 0    202  330    13   856   59   103   399    537    883     59    1   616  8
# 1    389  594    31  1109  116   126   759    380   1005    143    3   770  4
# 2    137  341     6   677   25    79   345    212    739    120    1   414  5
# 3    185  314    18   827   27   113   557    256    723    136    1   559  2

# %%
print(pos_counts.columns)
# Out:
# Index(['Doc', 'ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN',
#        'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'SYM', 'VERB', 'X'],
#       dtype='object')

# %%
average_pos_df = pos_counts.groupby(['NOUN']).mean()

average_pos_df = average_pos_df.round(0)

average_pos_df = average_pos_df.reset_index()

average_pos_df
# Out:
# /var/folders/dr/4wb40z7j5s15pks94r3cv3f00000gn/T/ipykernel_12772/2594417839.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#    NOUN    ADJ    ADP    ADV    AUX  CCONJ    DET  INTJ    NUM   PART   PRON  \
# 0   677  214.0  294.0  157.0  193.0  137.0  341.0   6.0   25.0   79.0  345.0
# 1   827  304.0  478.0  243.0  163.0  185.0  314.0  18.0   27.0  113.0  557.0
# 2   856  270.0  445.0  128.0  110.0  202.0  330.0  13.0   59.0  103.0  399.0
# 3  1109  371.0  567.0  261.0  338.0  389.0  594.0  31.0  116.0  126.0  759.0
#
#    PROPN   PUNCT  SCONJ  SYM   VERB    X
# 0  212.0   739.0  120.0  1.0  414.0  5.0
# 1  256.0   723.0  136.0  1.0  559.0  2.0
# 2  537.0   883.0   59.0  1.0  616.0  8.0
# 3  380.0  1005.0  143.0  3.0  770.0  4.0

# %% [markdown]
# ### summary
# Document 0:
# A large number of nouns (NOUN) may indicate that the document focuses more on describing and depicting things and concepts.
# A relatively low number of verbs (VERB) may mean fewer descriptions of behaviors or actions.
# Frequent use of punctuation marks (PUNCT) may indicate that the document has a strong sense of rhythm or a complex sentence structure.
# The greater use of pronouns (PRON) and proper nouns (PROPN) may indicate that the document describes specific names and persons more frequently.
#
#
# Document 1:
# Punctuation marks (PUNCT) are used more frequently, which may imply that the sentence structure of the document is more diverse and has a certain sense of rhythm.
# A higher number of verbs (VERB) may indicate that there are more parts of the document describing behaviors or actions.
# The frequent use of pronouns (PRON) may imply that specific persons or items are described more frequently in the document.
#
#
# Document 2:
# The number of punctuation marks (PUNCT) is significantly higher than other parts of speech, which may imply that the sentence structure of the document is relatively complex.
# Proper nouns (PROPN) are used more frequently, which may reflect the frequent descriptions of specific names, places, or people in the document.
# The relatively high number of verbs (VERB) and adjectives (ADJ) may indicate that the document contains more actions and adjective modifications.
#
#
# Document 3:
# The number of nouns (NOUN) and punctuation marks (PUNCT) is high, which may imply that the document has more descriptions of things and a strong sense of sentence rhythm.
# The number of pronouns (PRON) and verbs (VERB) is also relatively high, which may indicate that there are more personal descriptions and action descriptions in the document.
# These analyzes can help you understand some differences in grammatical features between different documents, or reveal the content style and characteristics expressed in the documents.

# %%
fig = px.bar(average_pos_df, x="NOUN", y=["ADJ", 'VERB', "NUM"], title="Average Part-of-Speech Use in Papers Written by Female Writers", barmode='group')
fig.show()
# Out:
# <div>                            <div id="56c64ef0-be4c-498b-b572-845ce7420eee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56c64ef0-be4c-498b-b572-845ce7420eee")) {                    Plotly.newPlot(                        "56c64ef0-be4c-498b-b572-845ce7420eee",                        [{"alignmentgroup":"True","hovertemplate":"variable=ADJ<br>NOUN=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ADJ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"ADJ","offsetgroup":"ADJ","orientation":"v","showlegend":true,"textposition":"auto","x":[677,827,856,1109],"xaxis":"x","y":[214.0,304.0,270.0,371.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=VERB<br>NOUN=%{x}<br>value=%{y}<extra></extra>","legendgroup":"VERB","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"VERB","offsetgroup":"VERB","orientation":"v","showlegend":true,"textposition":"auto","x":[677,827,856,1109],"xaxis":"x","y":[414.0,559.0,616.0,770.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=NUM<br>NOUN=%{x}<br>value=%{y}<extra></extra>","legendgroup":"NUM","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"NUM","offsetgroup":"NUM","orientation":"v","showlegend":true,"textposition":"auto","x":[677,827,856,1109],"xaxis":"x","y":[25.0,27.0,59.0,116.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %% [markdown]
# ### Analysis of ```DATE``` Named Entities

# %%
def extract_date_named_entities(doc):
    return [ent for ent in doc.ents if ent.label_ == 'DATE']

ner_analysis_df['Date_Named_Entities'] = final_paper_df['Doc'].apply(extract_date_named_entities)

ner_analysis_df['Date_Named_Entities'] = [', '.join(map(str, l)) for l in ner_analysis_df['Date_Named_Entities']]

# %%
date_word_counts_df = ner_analysis_df[(ner_analysis_df == 'Proposal').any(axis=1)]

date_word_frequencies = date_word_counts_df.Date_Named_Entities.str.split(expand=True).stack().value_counts()

date_word_frequencies[:10]
# Out:
# Series([], dtype: int64)

# %%
date_word_counts_df = ner_analysis_df[(ner_analysis_df == 'Critique/Evaluation').any(axis=1)]

date_word_frequencies = date_word_counts_df.Date_Named_Entities.str.split(expand=True).stack().value_counts()

date_word_frequencies[:10]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Conclusions
#
# Poems by Christina Georgina Rossetti:
#
# The higher frequency of commas, articles, conjunctions, and punctuation marks (such as double quotation marks, periods) may indicate that the author pays more attention to the flow of the storyline and the connection between sentences. The presence of female characters is emphasized, with names such as "Laura" and "Lizzie" appearing frequently, which may reflect the important role women play in the poem. Words about feelings and relationships appear frequently, possibly referring to feelings between women, friendships, or sisterhood.
#
#
# Poems by Edna St. Vincent Millay:
#
# Commas, articles, conjunctions, and punctuation marks also appear frequently, and attention is also paid to the connectivity of sentences. A high frequency of words related to personal pronouns (e.g., “I,” “you,” “she”) may indicate that the poem focuses more on the personal emotions and experiences of the author, reader, or other characters.
#
#
# Poems by Emily Dickinson, Series One by Emily Dickinson:
#
# Commas and punctuation marks appear more frequently, but articles and conjunctions appear less frequently. Time-related words such as "time", as well as pronouns and exclamation points are used more frequently, which may point to thinking or reflection on time, emotion and life.
#
#
# Sonnets from the Portuguese by Elizabeth Barrett Browning:
#
# Highlights the expression of love and emotion. The frequent occurrence of words such as "love", "soul" and "heart" reflects the author's strong focus on emotions and inner experience.
#
# Additionally，Analyzing the number of various parts of speech provides some grammatical analysis clues to help us understand the possible grammatical characteristics and style of each document.
#
# First, the noun (NOUN) and verb (VERB) are probably the most meaningful parts because they directly reflect the content and action of the document. Of the four documents, Sonnets from the Portuguese by Elizabeth Barrett Browning has the highest number of nouns and verbs, which may indicate that it is more action- and description-focused, while Poems by Christina Georgina Rossetti has the fewest nouns and verbs, which may be more oriented towards Description and abstraction.
#
# Adjectives (ADJ) and adverbs (ADV) are also very important parts of speech. They are usually used to describe nouns and verbs, helping readers perceive the text more clearly. Poems by Edna St. Vincent Millay has a relatively high number of adjectives and adverbs, which may indicate that it is richer in description and modification. Sonnets from the Portuguese by Elizabeth Barrett Browning has more adverbs, which may increase the detail of actions and descriptions.
#
# The number of punctuation marks (PUNCT) is also important. Sonnets from the Portuguese by Elizabeth Barrett Browning has the highest number of punctuation marks, possibly indicating a more complex or expressive syntactic structure, while Poems by Christina Georgina Rossetti uses relatively little punctuation and may have a more concise or direct sentence structure. .
#
# Finally, the number of proper nouns (PROPNs) may reflect the use of specific names or names in the document. Sonnets from the Portuguese by Elizabeth Barrett Browning has a higher number of proper nouns and may contain more specific places, names of people, or specific names, whereas other documents have relatively few.
